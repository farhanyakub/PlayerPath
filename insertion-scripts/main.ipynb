# %%
from nba_api.stats.endpoints import PlayerCareerStats
from nba_api.stats.static import players, teams
import pandas as pd

# dataframe to hold all the relevant information about the players
column_names = ['Player Full Name', 'Player First Name', 'Player Last Name', 'Player API ID', 'Teams']
player_df = pd.DataFrame(columns=column_names)

# gets all active nba players right now 
active_players = players.get_active_players()

# loops through every player in active players and gets relevant information
for player in active_players:
    id = player['id']
    player_stats = PlayerCareerStats(player_id=id).get_data_frames()[0]
    player_teams_id = []

    # get the team ids of the team player has played for
    for team in player_stats['TEAM_ID']:
        if team == 0:
            continue
        # this checks to make sure no duplicate teams are added unless they went back to the team (eg: Lebron)
        if len(player_teams_id) > 0 and team == player_teams_id[-1]:
            continue
        player_teams_id.append(team)

    # gets the names of the team players have played for from ids
    player_team_names = []
    for team in player_teams_id:
        player_team_names.append(teams.find_team_name_by_id(team)['full_name'])

    # other relevant information that will be added to the database
    full_name = player['full_name']
    first_name = player['first_name']
    last_name = player['last_name']
    new_entry = {
        'Player Full Name': full_name,
        'Player First Name': first_name,
        'Player Last Name': last_name,
        'Player API ID': id,
        'Teams': player_team_names
    }
    # adds the player info to the dataframe
    player_df.loc[len(player_df)] = new_entry

# creates a csv file with the player info for future use
player_df.to_csv('final_player_df.csv')

# %%
# dataframe created to hold relevant team information
team_columns = ['Team Name', 'Location', 'Nickname', 'Team API ID', 'Image URL']
team_df = pd.DataFrame(columns=team_columns)

# image logo for teams (need to add more which is done in the for loop)
image_url = "https://cdn.nba.com/logos/nba/"

# gets all the teams from the api and loops through them and adds relevant info to the df
all_teams = teams.get_teams()
for team in all_teams:
    team_entry = {
        'Team Name': team['full_name'],
        'Location': team['city'],
        'Nickname': team['nickname'],
        'Team API ID': team['id'],
        'Image URL': image_url + str(team['id']) + "/primary/L/logo.svg"
    }
    team_df.loc[len(team_df)] = team_entry

# writes the dataframe to a csv file for further use
team_df.to_csv('final_team.csv')

# %%
# insertion into the player table
import pandas as pd

print("INSERT INTO player(playerID, playerFullName, firstName, lastName, playerApiID) \n VALUES")
player_df = pd.read_csv('final_player_df.csv')
for index, row in player_df.iterrows():
    playerID = index
    playerFullName = row['Player Full Name']
    firstName = row['Player First Name']
    lastName = row['Player Last Name']
    playerApiID = row['Player API ID']

    print(f'({playerID}, "{playerFullName}", "{firstName}", "{lastName}", {playerApiID}),')
# Out:
# INSERT INTO player(playerID, playerFullName, firstName, lastName, playerApiID)
#  VALUES
# (0, "Precious Achiuwa", "Precious", "Achiuwa", 1630173),
# (1, "Steven Adams", "Steven", "Adams", 203500),
# (2, "Bam Adebayo", "Bam", "Adebayo", 1628389),
# (3, "Ochai Agbaji", "Ochai", "Agbaji", 1630534),
# (4, "Santi Aldama", "Santi", "Aldama", 1630583),
# (5, "Nickeil Alexander-Walker", "Nickeil", "Alexander-Walker", 1629638),
# (6, "Grayson Allen", "Grayson", "Allen", 1628960),
# (7, "Jarrett Allen", "Jarrett", "Allen", 1628386),
# (8, "Jose Alvarado", "Jose", "Alvarado", 1630631),
# (9, "Kyle Anderson", "Kyle", "Anderson", 203937),
# (10, "Giannis Antetokounmpo", "Giannis", "Antetokounmpo", 203507),
# (11, "Thanasis Antetokounmpo", "Thanasis", "Antetokounmpo", 203648),
# (12, "Cole Anthony", "Cole", "Anthony", 1630175),
# (13, "OG Anunoby", "OG", "Anunoby", 1628384),
# (14, "Ryan Arcidiacono", "Ryan", "Arcidiacono", 1627853),
# (15, "Deni Avdija", "Deni", "Avdija", 1630166),
# (16, "Deandre Ayton", "Deandre", "Ayton", 1629028),
# (17, "Udoka Azubuike", "Udoka", "Azubuike", 1628962),
# (18, "Marvin Bagley III", "Marvin", "Bagley III", 1628963),
# (19, "Amari Bailey", "Amari", "Bailey", 1641735),
# (20, "Patrick Baldwin Jr.", "Patrick", "Baldwin Jr.", 1631116),
# (21, "LaMelo Ball", "LaMelo", "Ball", 1630163),
# (22, "Lonzo Ball", "Lonzo", "Ball", 1628366),
# (23, "Mo Bamba", "Mo", "Bamba", 1628964),
# (24, "Paolo Banchero", "Paolo", "Banchero", 1631094),
# (25, "Desmond Bane", "Desmond", "Bane", 1630217),
# (26, "Dalano Banton", "Dalano", "Banton", 1630625),
# (27, "Dominick Barlow", "Dominick", "Barlow", 1631230),
# (28, "Harrison Barnes", "Harrison", "Barnes", 203084),
# (29, "Scottie Barnes", "Scottie", "Barnes", 1630567),
# (30, "RJ Barrett", "RJ", "Barrett", 1629628),
# (31, "Charles Bassey", "Charles", "Bassey", 1629646),
# (32, "Emoni Bates", "Emoni", "Bates", 1641734),
# (33, "Keita Bates-Diop", "Keita", "Bates-Diop", 1628966),
# (34, "Nicolas Batum", "Nicolas", "Batum", 201587),
# (35, "Bradley Beal", "Bradley", "Beal", 203078),
# (36, "Malik Beasley", "Malik", "Beasley", 1627736),
# (37, "MarJon Beauchamp", "MarJon", "Beauchamp", 1630699),
# (38, "Davis Bertans", "Davis", "Bertans", 202722),
# (39, "Patrick Beverley", "Patrick", "Beverley", 201976),
# (40, "Saddiq Bey", "Saddiq", "Bey", 1630180),
# (41, "Goga Bitadze", "Goga", "Bitadze", 1629048),
# (42, "Onuralp Bitim", "Onuralp", "Bitim", 1641931),
# (43, "Bismack Biyombo", "Bismack", "Biyombo", 202687),
# (44, "Anthony Black", "Anthony", "Black", 1641710),
# (45, "Leaky Black", "Leaky", "Black", 1641778),
# (46, "Bogdan Bogdanovic", "Bogdan", "Bogdanovic", 203992),
# (47, "Bojan Bogdanovic", "Bojan", "Bogdanovic", 202711),
# (48, "Bol Bol", "Bol", "Bol", 1629626),
# (49, "Marques Bolden", "Marques", "Bolden", 1629716),
# (50, "Devin Booker", "Devin", "Booker", 1626164),
# (51, "Brandon Boston Jr.", "Brandon", "Boston Jr.", 1630527),
# (52, "Chris Boucher", "Chris", "Boucher", 1628449),
# (53, "James Bouknight", "James", "Bouknight", 1630547),
# (54, "Malaki Branham", "Malaki", "Branham", 1631103),
# (55, "Christian Braun", "Christian", "Braun", 1631128),
# (56, "Mikal Bridges", "Mikal", "Bridges", 1628969),
# (57, "Miles Bridges", "Miles", "Bridges", 1628970),
# (58, "Oshae Brissett", "Oshae", "Brissett", 1629052),
# (59, "Malcolm Brogdon", "Malcolm", "Brogdon", 1627763),
# (60, "Armoni Brooks", "Armoni", "Brooks", 1629717),
# (61, "Dillon Brooks", "Dillon", "Brooks", 1628415),
# (62, "Bruce Brown", "Bruce", "Brown", 1628971),
# (63, "Jaylen Brown", "Jaylen", "Brown", 1627759),
# (64, "Kendall Brown", "Kendall", "Brown", 1631112),
# (65, "Kobe Brown", "Kobe", "Brown", 1641738),
# (66, "Moses Brown", "Moses", "Brown", 1629650),
# (67, "Greg Brown III", "Greg", "Brown III", 1630535),
# (68, "Charlie Brown Jr.", "Charlie", "Brown Jr.", 1629718),
# (69, "Troy Brown Jr.", "Troy", "Brown Jr.", 1628972),
# (70, "Jalen Brunson", "Jalen", "Brunson", 1628973),
# (71, "Thomas Bryant", "Thomas", "Bryant", 1628418),
# (72, "Kobe Bufkin", "Kobe", "Bufkin", 1641723),
# (73, "Reggie Bullock Jr.", "Reggie", "Bullock Jr.", 203493),
# (74, "Alec Burks", "Alec", "Burks", 202692),
# (75, "Jared Butler", "Jared", "Butler", 1630215),
# (76, "Jimmy Butler", "Jimmy", "Butler", 202710),
# (77, "John Butler Jr.", "John", "Butler Jr.", 1631219),
# (78, "Jamal Cain", "Jamal", "Cain", 1631288),
# (79, "Kentavious Caldwell-Pope", "Kentavious", "Caldwell-Pope", 203484),
# (80, "Toumani Camara", "Toumani", "Camara", 1641739),
# (81, "Vlatko Cancar", "Vlatko", "Cancar", 1628427),
# (82, "Clint Capela", "Clint", "Capela", 203991),
# (83, "Jevon Carter", "Jevon", "Carter", 1628975),
# (84, "Wendell Carter Jr.", "Wendell", "Carter Jr.", 1628976),
# (85, "Alex Caruso", "Alex", "Caruso", 1627936),
# (86, "Colin Castleton", "Colin", "Castleton", 1630658),
# (87, "Malcolm Cazalon", "Malcolm", "Cazalon", 1630608),
# (88, "Julian Champagnie", "Julian", "Champagnie", 1630577),
# (89, "Max Christie", "Max", "Christie", 1631108),
# (90, "Josh Christopher", "Josh", "Christopher", 1630528),
# (91, "Sidy Cissoko", "Sidy", "Cissoko", 1631321),
# (92, "Brandon Clarke", "Brandon", "Clarke", 1629634),
# (93, "Jordan Clarkson", "Jordan", "Clarkson", 203903),
# (94, "Nic Claxton", "Nic", "Claxton", 1629651),
# (95, "Noah Clowney", "Noah", "Clowney", 1641730),
# (96, "Amir Coffey", "Amir", "Coffey", 1629599),
# (97, "John Collins", "John", "Collins", 1628381),
# (98, "Zach Collins", "Zach", "Collins", 1628380),
# (99, "Mike Conley", "Mike", "Conley", 201144),
# (100, "Pat Connaughton", "Pat", "Connaughton", 1626192),
# (101, "Bilal Coulibaly", "Bilal", "Coulibaly", 1641731),
# (102, "Robert Covington", "Robert", "Covington", 203496),
# (103, "Torrey Craig", "Torrey", "Craig", 1628470),
# (104, "Jae Crowder", "Jae", "Crowder", 203109),
# (105, "Cade Cunningham", "Cade", "Cunningham", 1630595),
# (106, "Seth Curry", "Seth", "Curry", 203552),
# (107, "Stephen Curry", "Stephen", "Curry", 201939),
# (108, "Dyson Daniels", "Dyson", "Daniels", 1630700),
# (109, "Anthony Davis", "Anthony", "Davis", 203076),
# (110, "Johnny Davis", "Johnny", "Davis", 1631098),
# (111, "JD Davison", "JD", "Davison", 1631120),
# (112, "DeMar DeRozan", "DeMar", "DeRozan", 201942),
# (113, "Dexter Dennis", "Dexter", "Dennis", 1641926),
# (114, "Donte DiVincenzo", "Donte", "DiVincenzo", 1628978),
# (115, "Moussa Diabate", "Moussa", "Diabate", 1631217),
# (116, "Gradey Dick", "Gradey", "Dick", 1641711),
# (117, "Ousmane Dieng", "Ousmane", "Dieng", 1631172),
# (118, "Spencer Dinwiddie", "Spencer", "Dinwiddie", 203915),
# (119, "Luka Doncic", "Luka", "Doncic", 1629029),
# (120, "Luguentz Dort", "Luguentz", "Dort", 1629652),
# (121, "Ayo Dosunmu", "Ayo", "Dosunmu", 1630245),
# (122, "Andre Drummond", "Andre", "Drummond", 203083),
# (123, "Chris Duarte", "Chris", "Duarte", 1630537),
# (124, "Kris Dunn", "Kris", "Dunn", 1627739),
# (125, "Kevin Durant", "Kevin", "Durant", 201142),
# (126, "Jalen Duren", "Jalen", "Duren", 1631105),
# (127, "Tari Eason", "Tari", "Eason", 1631106),
# (128, "Anthony Edwards", "Anthony", "Edwards", 1630162),
# (129, "Kessler Edwards", "Kessler", "Edwards", 1630556),
# (130, "Keon Ellis", "Keon", "Ellis", 1631165),
# (131, "Joel Embiid", "Joel", "Embiid", 203954),
# (132, "Drew Eubanks", "Drew", "Eubanks", 1629234),
# (133, "Dante Exum", "Dante", "Exum", 203957),
# (134, "Bruno Fernando", "Bruno", "Fernando", 1628981),
# (135, "Dorian Finney-Smith", "Dorian", "Finney-Smith", 1627827),
# (136, "Malachi Flynn", "Malachi", "Flynn", 1630201),
# (137, "Simone Fontecchio", "Simone", "Fontecchio", 1631323),
# (138, "Jordan Ford", "Jordan", "Ford", 1630259),
# (139, "Trent Forrest", "Trent", "Forrest", 1630235),
# (140, "Evan Fournier", "Evan", "Fournier", 203095),
# (141, "De'Aaron Fox", "De'Aaron", "Fox", 1628368),
# (142, "Alex Fudge", "Alex", "Fudge", 1641788),
# (143, "Markelle Fultz", "Markelle", "Fultz", 1628365),
# (144, "Daniel Gafford", "Daniel", "Gafford", 1629655),
# (145, "Danilo Gallinari", "Danilo", "Gallinari", 201568),
# (146, "Darius Garland", "Darius", "Garland", 1629636),
# (147, "Usman Garuba", "Usman", "Garuba", 1630586),
# (148, "Luka Garza", "Luka", "Garza", 1630568),
# (149, "Kaiser Gates", "Kaiser", "Gates", 1629232),
# (150, "Keyonte George", "Keyonte", "George", 1641718),
# (151, "Paul George", "Paul", "George", 202331),
# (152, "Josh Giddey", "Josh", "Giddey", 1630581),
# (153, "Harry Giles III", "Harry", "Giles III", 1628385),
# (154, "Shai Gilgeous-Alexander", "Shai", "Gilgeous-Alexander", 1628983),
# (155, "Anthony Gill", "Anthony", "Gill", 1630264),
# (156, "Collin Gillespie", "Collin", "Gillespie", 1631221),
# (157, "Jacob Gilyard", "Jacob", "Gilyard", 1631367),
# (158, "Rudy Gobert", "Rudy", "Gobert", 203497),
# (159, "Jordan Goodwin", "Jordan", "Goodwin", 1630692),
# (160, "Aaron Gordon", "Aaron", "Gordon", 203932),
# (161, "Eric Gordon", "Eric", "Gordon", 201569),
# (162, "Devonte' Graham", "Devonte'", "Graham", 1628984),
# (163, "Jerami Grant", "Jerami", "Grant", 203924),
# (164, "AJ Green", "AJ", "Green", 1631260),
# (165, "Danny Green", "Danny", "Green", 201980),
# (166, "Draymond Green", "Draymond", "Green", 203110),
# (167, "Jalen Green", "Jalen", "Green", 1630224),
# (168, "Jeff Green", "Jeff", "Green", 201145),
# (169, "Josh Green", "Josh", "Green", 1630182),
# (170, "AJ Griffin", "AJ", "Griffin", 1631100),
# (171, "Quentin Grimes", "Quentin", "Grimes", 1629656),
# (172, "Mouhamed Gueye", "Mouhamed", "Gueye", 1631243),
# (173, "Rui Hachimura", "Rui", "Hachimura", 1629060),
# (174, "Tyrese Haliburton", "Tyrese", "Haliburton", 1630169),
# (175, "R.J. Hampton", "R.J.", "Hampton", 1630181),
# (176, "Tim Hardaway Jr.", "Tim", "Hardaway Jr.", 203501),
# (177, "James Harden", "James", "Harden", 201935),
# (178, "Jaden Hardy", "Jaden", "Hardy", 1630702),
# (179, "Ron Harper Jr.", "Ron", "Harper Jr.", 1631199),
# (180, "Gary Harris", "Gary", "Harris", 203914),
# (181, "Joe Harris", "Joe", "Harris", 203925),
# (182, "Kevon Harris", "Kevon", "Harris", 1630284),
# (183, "Tobias Harris", "Tobias", "Harris", 202699),
# (184, "Josh Hart", "Josh", "Hart", 1628404),
# (185, "Isaiah Hartenstein", "Isaiah", "Hartenstein", 1628392),
# (186, "Sam Hauser", "Sam", "Hauser", 1630573),
# (187, "Jordan Hawkins", "Jordan", "Hawkins", 1641722),
# (188, "Jaxson Hayes", "Jaxson", "Hayes", 1629637),
# (189, "Killian Hayes", "Killian", "Hayes", 1630165),
# (190, "Gordon Hayward", "Gordon", "Hayward", 202330),
# (191, "Scoot Henderson", "Scoot", "Henderson", 1630703),
# (192, "Taylor Hendricks", "Taylor", "Hendricks", 1641707),
# (193, "Tyler Herro", "Tyler", "Herro", 1629639),
# (194, "Buddy Hield", "Buddy", "Hield", 1627741),
# (195, "Haywood Highsmith", "Haywood", "Highsmith", 1629312),
# (196, "Nate Hinton", "Nate", "Hinton", 1630207),
# (197, "D'Moi Hodge", "D'Moi", "Hodge", 1641793),
# (198, "Aaron Holiday", "Aaron", "Holiday", 1628988),
# (199, "Jrue Holiday", "Jrue", "Holiday", 201950),
# (200, "Justin Holiday", "Justin", "Holiday", 203200),
# (201, "Richaun Holmes", "Richaun", "Holmes", 1626158),
# (202, "Chet Holmgren", "Chet", "Holmgren", 1631096),
# (203, "Jalen Hood-Schifino", "Jalen", "Hood-Schifino", 1641720),
# (204, "Al Horford", "Al", "Horford", 201143),
# (205, "Talen Horton-Tucker", "Talen", "Horton-Tucker", 1629659),
# (206, "Danuel House Jr.", "Danuel", "House Jr.", 1627863),
# (207, "Caleb Houstan", "Caleb", "Houstan", 1631216),
# (208, "Jett Howard", "Jett", "Howard", 1641724),
# (209, "Kevin Huerter", "Kevin", "Huerter", 1628989),
# (210, "Jay Huff", "Jay", "Huff", 1630643),
# (211, "De'Andre Hunter", "De'Andre", "Hunter", 1629631),
# (212, "Bones Hyland", "Bones", "Hyland", 1630538),
# (213, "Joe Ingles", "Joe", "Ingles", 204060),
# (214, "Brandon Ingram", "Brandon", "Ingram", 1627742),
# (215, "Kyrie Irving", "Kyrie", "Irving", 202681),
# (216, "Jonathan Isaac", "Jonathan", "Isaac", 1628371),
# (217, "Jaden Ivey", "Jaden", "Ivey", 1631093),
# (218, "GG Jackson", "GG", "Jackson", 1641713),
# (219, "Isaiah Jackson", "Isaiah", "Jackson", 1630543),
# (220, "Reggie Jackson", "Reggie", "Jackson", 202704),
# (221, "Andre Jackson Jr.", "Andre", "Jackson Jr.", 1641748),
# (222, "Jaren Jackson Jr.", "Jaren", "Jackson Jr.", 1628991),
# (223, "Trayce Jackson-Davis", "Trayce", "Jackson-Davis", 1631218),
# (224, "LeBron James", "LeBron", "James", 2544),
# (225, "Jaime Jaquez Jr.", "Jaime", "Jaquez Jr.", 1631170),
# (226, "DaQuan Jeffries", "DaQuan", "Jeffries", 1629610),
# (227, "Ty Jerome", "Ty", "Jerome", 1629660),
# (228, "Isaiah Joe", "Isaiah", "Joe", 1630198),
# (229, "Cameron Johnson", "Cameron", "Johnson", 1629661),
# (230, "Jalen Johnson", "Jalen", "Johnson", 1630552),
# (231, "Keldon Johnson", "Keldon", "Johnson", 1629640),
# (232, "Keon Johnson", "Keon", "Johnson", 1630553),
# (233, "Keyontae Johnson", "Keyontae", "Johnson", 1641749),
# (234, "Nikola Jokic", "Nikola", "Jokic", 203999),
# (235, "Colby Jones", "Colby", "Jones", 1641732),
# (236, "Damian Jones", "Damian", "Jones", 1627745),
# (237, "Herbert Jones", "Herbert", "Jones", 1630529),
# (238, "Tre Jones", "Tre", "Jones", 1630200),
# (239, "Tyus Jones", "Tyus", "Jones", 1626145),
# (240, "Derrick Jones Jr.", "Derrick", "Jones Jr.", 1627884),
# (241, "DeAndre Jordan", "DeAndre", "Jordan", 201599),
# (242, "Cory Joseph", "Cory", "Joseph", 202709),
# (243, "Nikola Jovic", "Nikola", "Jovic", 1631107),
# (244, "Johnny Juzang", "Johnny", "Juzang", 1630548),
# (245, "Luke Kennard", "Luke", "Kennard", 1628379),
# (246, "Walker Kessler", "Walker", "Kessler", 1631117),
# (247, "Braxton Key", "Braxton", "Key", 1630296),
# (248, "Corey Kispert", "Corey", "Kispert", 1630557),
# (249, "Maxi Kleber", "Maxi", "Kleber", 1628467),
# (250, "Nathan Knight", "Nathan", "Knight", 1630233),
# (251, "Kevin Knox II", "Kevin", "Knox II", 1628995),
# (252, "Christian Koloko", "Christian", "Koloko", 1631132),
# (253, "John Konchar", "John", "Konchar", 1629723),
# (254, "Furkan Korkmaz", "Furkan", "Korkmaz", 1627788),
# (255, "Luke Kornet", "Luke", "Kornet", 1628436),
# (256, "Jonathan Kuminga", "Jonathan", "Kuminga", 1630228),
# (257, "Kyle Kuzma", "Kyle", "Kuzma", 1628398),
# (258, "Jake LaRavia", "Jake", "LaRavia", 1631222),
# (259, "Zach LaVine", "Zach", "LaVine", 203897),
# (260, "Jock Landale", "Jock", "Landale", 1629111),
# (261, "A.J. Lawson", "A.J.", "Lawson", 1630639),
# (262, "Caris LeVert", "Caris", "LeVert", 1627747),
# (263, "Damion Lee", "Damion", "Lee", 1627814),
# (264, "Saben Lee", "Saben", "Lee", 1630240),
# (265, "Alex Len", "Alex", "Len", 203458),
# (266, "Kawhi Leonard", "Kawhi", "Leonard", 202695),
# (267, "Maxwell Lewis", "Maxwell", "Lewis", 1641721),
# (268, "Kira Lewis Jr.", "Kira", "Lewis Jr.", 1630184),
# (269, "E.J. Liddell", "E.J.", "Liddell", 1630604),
# (270, "Damian Lillard", "Damian", "Lillard", 203081),
# (271, "Nassir Little", "Nassir", "Little", 1629642),
# (272, "Dereck Lively II", "Dereck", "Lively II", 1641726),
# (273, "Isaiah Livers", "Isaiah", "Livers", 1630587),
# (274, "Chris Livingston", "Chris", "Livingston", 1641753),
# (275, "Kenneth Lofton Jr.", "Kenneth", "Lofton Jr.", 1631254),
# (276, "Kevon Looney", "Kevon", "Looney", 1626172),
# (277, "Brook Lopez", "Brook", "Lopez", 201572),
# (278, "Robin Lopez", "Robin", "Lopez", 201577),
# (279, "Kevin Love", "Kevin", "Love", 201567),
# (280, "Kyle Lowry", "Kyle", "Lowry", 200768),
# (281, "Seth Lundy", "Seth", "Lundy", 1641754),
# (282, "Trey Lyles", "Trey", "Lyles", 1626168),
# (283, "Theo Maledon", "Theo", "Maledon", 1630177),
# (284, "Sandro Mamukelashvili", "Sandro", "Mamukelashvili", 1630572),
# (285, "Terance Mann", "Terance", "Mann", 1629611),
# (286, "Tre Mann", "Tre", "Mann", 1630544),
# (287, "Boban Marjanovic", "Boban", "Marjanovic", 1626246),
# (288, "Lauri Markkanen", "Lauri", "Markkanen", 1628374),
# (289, "Naji Marshall", "Naji", "Marshall", 1630230),
# (290, "Caleb Martin", "Caleb", "Martin", 1628997),
# (291, "Cody Martin", "Cody", "Martin", 1628998),
# (292, "KJ Martin", "KJ", "Martin", 1630231),
# (293, "Garrison Mathews", "Garrison", "Mathews", 1629726),
# (294, "Bennedict Mathurin", "Bennedict", "Mathurin", 1631097),
# (295, "Wesley Matthews", "Wesley", "Matthews", 202083),
# (296, "Tyrese Maxey", "Tyrese", "Maxey", 1630178),
# (297, "Skylar Mays", "Skylar", "Mays", 1630219),
# (298, "Miles McBride", "Miles", "McBride", 1630540),
# (299, "CJ McCollum", "CJ", "McCollum", 203468),
# (300, "T.J. McConnell", "T.J.", "McConnell", 204456),
# (301, "Jaden McDaniels", "Jaden", "McDaniels", 1630183),
# (302, "Jalen McDaniels", "Jalen", "McDaniels", 1629667),
# (303, "Doug McDermott", "Doug", "McDermott", 203926),
# (304, "JaVale McGee", "JaVale", "McGee", 201580),
# (305, "Bryce McGowens", "Bryce", "McGowens", 1631121),
# (306, "Jordan McLaughlin", "Jordan", "McLaughlin", 1629162),
# (307, "De'Anthony Melton", "De'Anthony", "Melton", 1629001),
# (308, "Sam Merrill", "Sam", "Merrill", 1630241),
# (309, "Chimezie Metu", "Chimezie", "Metu", 1629002),
# (310, "Vasilije Micic", "Vasilije", "Micic", 203995),
# (311, "Khris Middleton", "Khris", "Middleton", 203114),
# (312, "Brandon Miller", "Brandon", "Miller", 1641706),
# (313, "Jordan Miller", "Jordan", "Miller", 1641757),
# (314, "Leonard Miller", "Leonard", "Miller", 1631159),
# (315, "Patty Mills", "Patty", "Mills", 201988),
# (316, "Shake Milton", "Shake", "Milton", 1629003),
# (317, "Justin Minaya", "Justin", "Minaya", 1631303),
# (318, "Josh Minott", "Josh", "Minott", 1631169),
# (319, "Davion Mitchell", "Davion", "Mitchell", 1630558),
# (320, "Donovan Mitchell", "Donovan", "Mitchell", 1628378),
# (321, "Evan Mobley", "Evan", "Mobley", 1630596),
# (322, "Isaiah Mobley", "Isaiah", "Mobley", 1630600),
# (323, "Malik Monk", "Malik", "Monk", 1628370),
# (324, "Moses Moody", "Moses", "Moody", 1630541),
# (325, "Wendell Moore Jr.", "Wendell", "Moore Jr.", 1631111),
# (326, "Ja Morant", "Ja", "Morant", 1629630),
# (327, "Markieff Morris", "Markieff", "Morris", 202693),
# (328, "Monte Morris", "Monte", "Morris", 1628420),
# (329, "Marcus Morris Sr.", "Marcus", "Morris Sr.", 202694),
# (330, "Trey Murphy III", "Trey", "Murphy III", 1630530),
# (331, "Dejounte Murray", "Dejounte", "Murray", 1627749),
# (332, "Jamal Murray", "Jamal", "Murray", 1627750),
# (333, "Keegan Murray", "Keegan", "Murray", 1631099),
# (334, "Kris Murray", "Kris", "Murray", 1631200),
# (335, "Mike Muscala", "Mike", "Muscala", 203488),
# (336, "Svi Mykhailiuk", "Svi", "Mykhailiuk", 1629004),
# (337, "Larry Nance Jr.", "Larry", "Nance Jr.", 1626204),
# (338, "Andrew Nembhard", "Andrew", "Nembhard", 1629614),
# (339, "Aaron Nesmith", "Aaron", "Nesmith", 1630174),
# (340, "Georges Niang", "Georges", "Niang", 1627777),
# (341, "Daishen Nix", "Daishen", "Nix", 1630227),
# (342, "Zeke Nnaji", "Zeke", "Nnaji", 1630192),
# (343, "Markquis Nowell", "Markquis", "Nowell", 1641806),
# (344, "Frank Ntilikina", "Frank", "Ntilikina", 1628373),
# (345, "Jusuf Nurkic", "Jusuf", "Nurkic", 203994),
# (346, "Jordan Nwora", "Jordan", "Nwora", 1629670),
# (347, "Royce O'Neale", "Royce", "O'Neale", 1626220),
# (348, "Chuma Okeke", "Chuma", "Okeke", 1629643),
# (349, "Josh Okogie", "Josh", "Okogie", 1629006),
# (350, "Onyeka Okongwu", "Onyeka", "Okongwu", 1630168),
# (351, "Isaac Okoro", "Isaac", "Okoro", 1630171),
# (352, "Victor Oladipo", "Victor", "Oladipo", 203506),
# (353, "Kelly Olynyk", "Kelly", "Olynyk", 203482),
# (354, "Eugene Omoruyi", "Eugene", "Omoruyi", 1630647),
# (355, "Cedi Osman", "Cedi", "Osman", 1626224),
# (356, "Kelly Oubre Jr.", "Kelly", "Oubre Jr.", 1626162),
# (357, "Chris Paul", "Chris", "Paul", 101108),
# (358, "Cameron Payne", "Cameron", "Payne", 1626166),
# (359, "Gary Payton II", "Gary", "Payton II", 1627780),
# (360, "Filip Petrusev", "Filip", "Petrusev", 1630196),
# (361, "Julian Phillips", "Julian", "Phillips", 1641763),
# (362, "Jalen Pickett", "Jalen", "Pickett", 1629618),
# (363, "Mason Plumlee", "Mason", "Plumlee", 203486),
# (364, "Brandin Podziemski", "Brandin", "Podziemski", 1641764),
# (365, "Jakob Poeltl", "Jakob", "Poeltl", 1627751),
# (366, "Aleksej Pokusevski", "Aleksej", "Pokusevski", 1630197),
# (367, "Jordan Poole", "Jordan", "Poole", 1629673),
# (368, "Craig Porter", "Craig", "Porter", 1641854),
# (369, "Michael Porter Jr.", "Michael", "Porter Jr.", 1629008),
# (370, "Otto Porter Jr.", "Otto", "Porter Jr.", 203490),
# (371, "Bobby Portis", "Bobby", "Portis", 1626171),
# (372, "Kristaps Porzingis", "Kristaps", "Porzingis", 204001),
# (373, "Micah Potter", "Micah", "Potter", 1630695),
# (374, "Dwight Powell", "Dwight", "Powell", 203939),
# (375, "Norman Powell", "Norman", "Powell", 1626181),
# (376, "Joshua Primo", "Joshua", "Primo", 1630563),
# (377, "Taurean Prince", "Taurean", "Prince", 1627752),
# (378, "Payton Pritchard", "Payton", "Pritchard", 1630202),
# (379, "Olivier-Maxence Prosper", "Olivier-Maxence", "Prosper", 1641765),
# (380, "Trevelin Queen", "Trevelin", "Queen", 1630243),
# (381, "Neemias Queta", "Neemias", "Queta", 1629674),
# (382, "Immanuel Quickley", "Immanuel", "Quickley", 1630193),
# (383, "Lester Quinones", "Lester", "Quinones", 1631311),
# (384, "Julius Randle", "Julius", "Randle", 203944),
# (385, "Duop Reath", "Duop", "Reath", 1641871),
# (386, "Austin Reaves", "Austin", "Reaves", 1630559),
# (387, "Cam Reddish", "Cam", "Reddish", 1629629),
# (388, "Paul Reed", "Paul", "Reed", 1630194),
# (389, "Naz Reid", "Naz", "Reid", 1629675),
# (390, "Jared Rhoden", "Jared", "Rhoden", 1631197),
# (391, "Nick Richards", "Nick", "Richards", 1630208),
# (392, "Josh Richardson", "Josh", "Richardson", 1626196),
# (393, "Duncan Robinson", "Duncan", "Robinson", 1629130),
# (394, "Jerome Robinson", "Jerome", "Robinson", 1629010),
# (395, "Mitchell Robinson", "Mitchell", "Robinson", 1629011),
# (396, "Orlando Robinson", "Orlando", "Robinson", 1631115),
# (397, "Jeremiah Robinson-Earl", "Jeremiah", "Robinson-Earl", 1630526),
# (398, "David Roddy", "David", "Roddy", 1631223),
# (399, "Ryan Rollins", "Ryan", "Rollins", 1631157),
# (400, "Derrick Rose", "Derrick", "Rose", 201565),
# (401, "Terry Rozier", "Terry", "Rozier", 1626179),
# (402, "Ricky Rubio", "Ricky", "Rubio", 201937),
# (403, "Rayan Rupert", "Rayan", "Rupert", 1641712),
# (404, "D'Angelo Russell", "D'Angelo", "Russell", 1626156),
# (405, "Matt Ryan", "Matt", "Ryan", 1630346),
# (406, "Domantas Sabonis", "Domantas", "Sabonis", 1627734),
# (407, "Luka Samanic", "Luka", "Samanic", 1629677),
# (408, "Jermaine Samuels Jr.", "Jermaine", "Samuels Jr.", 1631257),
# (409, "Gui Santos", "Gui", "Santos", 1630611),
# (410, "Dario Saric", "Dario", "Saric", 203967),
# (411, "Olivier Sarr", "Olivier", "Sarr", 1630846),
# (412, "Marcus Sasser", "Marcus", "Sasser", 1631204),
# (413, "Admiral Schofield", "Admiral", "Schofield", 1629678),
# (414, "Dennis Schroder", "Dennis", "Schroder", 203471),
# (415, "Dereon Seabron", "Dereon", "Seabron", 1631220),
# (416, "Alperen Sengun", "Alperen", "Sengun", 1630578),
# (417, "Brice Sensabaugh", "Brice", "Sensabaugh", 1641729),
# (418, "Collin Sexton", "Collin", "Sexton", 1629012),
# (419, "Landry Shamet", "Landry", "Shamet", 1629013),
# (420, "Day'Ron Sharpe", "Day'Ron", "Sharpe", 1630549),
# (421, "Shaedon Sharpe", "Shaedon", "Sharpe", 1631101),
# (422, "Ben Sheppard", "Ben", "Sheppard", 1641767),
# (423, "Pascal Siakam", "Pascal", "Siakam", 1627783),
# (424, "Ben Simmons", "Ben", "Simmons", 1627732),
# (425, "Anfernee Simons", "Anfernee", "Simons", 1629014),
# (426, "Jericho Sims", "Jericho", "Sims", 1630579),
# (427, "Jalen Slawson", "Jalen", "Slawson", 1641771),
# (428, "Javonte Smart", "Javonte", "Smart", 1630606),
# (429, "Marcus Smart", "Marcus", "Smart", 203935),
# (430, "Dru Smith", "Dru", "Smith", 1630696),
# (431, "Ish Smith", "Ish", "Smith", 202397),
# (432, "Jalen Smith", "Jalen", "Smith", 1630188),
# (433, "Dennis Smith Jr.", "Dennis", "Smith Jr.", 1628372),
# (434, "Jabari Smith Jr.", "Jabari", "Smith Jr.", 1631095),
# (435, "Nick Smith Jr.", "Nick", "Smith Jr.", 1641733),
# (436, "Jeremy Sochan", "Jeremy", "Sochan", 1631110),
# (437, "Jaden Springer", "Jaden", "Springer", 1630531),
# (438, "Lamar Stevens", "Lamar", "Stevens", 1630205),
# (439, "Isaiah Stewart", "Isaiah", "Stewart", 1630191),
# (440, "Julian Strawther", "Julian", "Strawther", 1631124),
# (441, "Max Strus", "Max", "Strus", 1629622),
# (442, "Jalen Suggs", "Jalen", "Suggs", 1630591),
# (443, "Cole Swider", "Cole", "Swider", 1631306),
# (444, "Jae'Sean Tate", "Jae'Sean", "Tate", 1630256),
# (445, "Jayson Tatum", "Jayson", "Tatum", 1628369),
# (446, "Terry Taylor", "Terry", "Taylor", 1630678),
# (447, "Garrett Temple", "Garrett", "Temple", 202066),
# (448, "Dalen Terry", "Dalen", "Terry", 1631207),
# (449, "Daniel Theis", "Daniel", "Theis", 1628464),
# (450, "Cam Thomas", "Cam", "Thomas", 1630560),
# (451, "Amen Thompson", "Amen", "Thompson", 1641708),
# (452, "Ausar Thompson", "Ausar", "Thompson", 1641709),
# (453, "Klay Thompson", "Klay", "Thompson", 202691),
# (454, "Tristan Thompson", "Tristan", "Thompson", 202684),
# (455, "JT Thor", "JT", "Thor", 1630550),
# (456, "Matisse Thybulle", "Matisse", "Thybulle", 1629680),
# (457, "Xavier Tillman", "Xavier", "Tillman", 1630214),
# (458, "Jacob Toppin", "Jacob", "Toppin", 1631210),
# (459, "Obi Toppin", "Obi", "Toppin", 1630167),
# (460, "Karl-Anthony Towns", "Karl-Anthony", "Towns", 1626157),
# (461, "Gary Trent Jr.", "Gary", "Trent Jr.", 1629018),
# (462, "Oscar Tshiebwe", "Oscar", "Tshiebwe", 1631131),
# (463, "P.J. Tucker", "P.J.", "Tucker", 200782),
# (464, "Myles Turner", "Myles", "Turner", 1626167),
# (465, "Hunter Tyson", "Hunter", "Tyson", 1641816),
# (466, "Stanley Umude", "Stanley", "Umude", 1630649),
# (467, "Jonas Valanciunas", "Jonas", "Valanciunas", 202685),
# (468, "Fred VanVleet", "Fred", "VanVleet", 1627832),
# (469, "Jarred Vanderbilt", "Jarred", "Vanderbilt", 1629020),
# (470, "Devin Vassell", "Devin", "Vassell", 1630170),
# (471, "Sasha Vezenkov", "Sasha", "Vezenkov", 1628426),
# (472, "Gabe Vincent", "Gabe", "Vincent", 1629216),
# (473, "Nikola Vucevic", "Nikola", "Vucevic", 202696),
# (474, "Dean Wade", "Dean", "Wade", 1629731),
# (475, "Franz Wagner", "Franz", "Wagner", 1630532),
# (476, "Moritz Wagner", "Moritz", "Wagner", 1629021),
# (477, "Ish Wainright", "Ish", "Wainright", 1630688),
# (478, "Jabari Walker", "Jabari", "Walker", 1631133),
# (479, "Jarace Walker", "Jarace", "Walker", 1641716),
# (480, "Lonnie Walker IV", "Lonnie", "Walker IV", 1629022),
# (481, "Cason Wallace", "Cason", "Wallace", 1641717),
# (482, "P.J. Washington", "P.J.", "Washington", 1629023),
# (483, "Duane Washington Jr.", "Duane", "Washington Jr.", 1630613),
# (484, "TyTy Washington Jr.", "TyTy", "Washington Jr.", 1631102),
# (485, "Yuta Watanabe", "Yuta", "Watanabe", 1629139),
# (486, "Lindy Waters III", "Lindy", "Waters III", 1630322),
# (487, "Trendon Watford", "Trendon", "Watford", 1630570),
# (488, "Peyton Watson", "Peyton", "Watson", 1631212),
# (489, "Victor Wembanyama", "Victor", "Wembanyama", 1641705),
# (490, "Blake Wesley", "Blake", "Wesley", 1631104),
# (491, "Russell Westbrook", "Russell", "Westbrook", 201566),
# (492, "Coby White", "Coby", "White", 1629632),
# (493, "Derrick White", "Derrick", "White", 1628401),
# (494, "Dariq Whitehead", "Dariq", "Whitehead", 1641727),
# (495, "Cam Whitmore", "Cam", "Whitmore", 1641715),
# (496, "Aaron Wiggins", "Aaron", "Wiggins", 1630598),
# (497, "Andrew Wiggins", "Andrew", "Wiggins", 203952),
# (498, "Lindell Wigginton", "Lindell", "Wigginton", 1629623),
# (499, "Grant Williams", "Grant", "Williams", 1629684),
# (500, "Jalen Williams", "Jalen", "Williams", 1631114),
# (501, "Jaylin Williams", "Jaylin", "Williams", 1631119),
# (502, "Kenrich Williams", "Kenrich", "Williams", 1629026),
# (503, "Mark Williams", "Mark", "Williams", 1631109),
# (504, "Nate Williams", "Nate", "Williams", 1631466),
# (505, "Patrick Williams", "Patrick", "Williams", 1630172),
# (506, "Ziaire Williams", "Ziaire", "Williams", 1630533),
# (507, "Robert Williams III", "Robert", "Williams III", 1629057),
# (508, "Vince Williams Jr.", "Vince", "Williams Jr.", 1631246),
# (509, "Zion Williamson", "Zion", "Williamson", 1629627),
# (510, "Jalen Wilson", "Jalen", "Wilson", 1630592),
# (511, "Dylan Windler", "Dylan", "Windler", 1629685),
# (512, "James Wiseman", "James", "Wiseman", 1630164),
# (513, "Christian Wood", "Christian", "Wood", 1626174),
# (514, "Delon Wright", "Delon", "Wright", 1626153),
# (515, "Thaddeus Young", "Thaddeus", "Young", 201152),
# (516, "Trae Young", "Trae", "Young", 1629027),
# (517, "Omer Yurtseven", "Omer", "Yurtseven", 1630209),
# (518, "Cody Zeller", "Cody", "Zeller", 203469),
# (519, "Ivica Zubac", "Ivica", "Zubac", 1627826),

# %%
# insertion into team table
team_df = pd.read_csv('final_team.csv')
print("INSERT INTO team(teamID, teamFullName, location, nickname, teamApiID, imageURL) \n VALUES")
for index, row in team_df.iterrows():
    teamID = index
    teamFullName = row['Team Name']
    location = row['Location']
    nickname = row['Nickname']
    teamApiID = row['Team API ID']
    imageURL = row['Image URL']
    
    print(f'({teamID}, "{teamFullName}", "{location}", "{nickname}", {teamApiID}, "{imageURL}"),')

# %%
# insertion into the playedFor table
import ast

print("INSERT INTO playedFor(playerID, teamID, duplicateID) \n VALUES")
player_df = pd.read_csv('final_player_df.csv')
team_df = pd.read_csv('final_team.csv')
for player_index, row in player_df.iterrows():
    player_teams = ast.literal_eval(row['Teams'])
    count = 0
    for team in player_teams:
        for team_index, row in team_df.iterrows():
            if team == row['Team Name']:
                print(f'({player_index}, {team_index}, {count}),')
                count += 1
                break
